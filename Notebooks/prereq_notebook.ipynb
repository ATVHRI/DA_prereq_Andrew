# %%
print("Hello DA world!")

# %%
# About Me

Hi! My name is Andrew. I'm excited to learn data analytics and get more comfortable with Python, Git, and VS Code. Looking forward to growing my skills throughout my time
in the course and hope it leads me to success!
